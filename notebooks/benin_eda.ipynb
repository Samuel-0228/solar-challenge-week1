# %%
# Placeholder: Assume data/benin.csv exists locally (don't commit)
df = pd.read_csv('data/benin.csv')  # Error OK for now—demo structure
print(df.head())  # Shows first 5 rows
# Out:
# Running cells with '.venv (3.12.7) (Python 3.12.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Hp/solar-challenge-week1/.venv/bin/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
# Assume GHI column—quick histogram
if 'GHI' in df.columns:
    df['GHI'].hist(bins=20)
    plt.title("Quick GHI Histogram (Benin Placeholder)")
    plt.xlabel("GHI (W/m²)")
    plt.ylabel("Frequency")
    plt.show()
else:
    print("No GHI column yet—add fake data above!")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline  # Makes plots show inline (VS Code/Jupyter)
